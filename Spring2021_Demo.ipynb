# %% [markdown]
# <a href="https://colab.research.google.com/github/systemsfundamentalspartI/Methods-in-Complex-Systems/blob/main/Spring2021_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Demo Spring 2021

# %%
2+2
# Out:
# 4

# %%
2**12345
# Out:
# ...
